# %%
import requests
from bs4 import BeautifulSoup
import random
import pandas as pd
from datetime import datetime

# %%
# Parámetros de búsqueda
title = "analista de datos"
location = "UniteStates"

# %%
list_url = "https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=analista%2Bde%2Bdatos&location=UnitesStates&start=50" #editar link 
response = requests.get(list_url)

#https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=analista%2Bde%2Bdatos&location=colombia&geoId=&trk=public_jobs_jobs-search-bar_search-submit&start=25

list_data = response.text 
list_soup = BeautifulSoup(list_data, "html.parser")
page_jobs = list_soup.find_all("li")

# %%
# URL base para la paginación
base_url = "https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search"
id_list = []

# Lógica para paginar y obtener más IDs
for start in range(0, 200, 25):  # Cambiar 200 según el número máximo deseado
    list_url = f"{base_url}?keywords={title.replace(' ', '%2B')}&location={location}&start={start}"
    response = requests.get(list_url)
    if response.status_code != 200:
        print(f"Error al obtener datos de la página con inicio {start}")
        break
    list_data = response.text
    list_soup = BeautifulSoup(list_data, "html.parser")
    page_jobs = list_soup.find_all("li")

    # Extraer IDs de los trabajos
    for job in page_jobs:
        try:
            base_card_div = job.find("div", {"class": "base-card"})
            if base_card_div:
                job_id = base_card_div.get("data-entity-urn").split(":")[3]
                id_list.append(job_id)
        except AttributeError:
            continue

# Limitar el número de IDs a procesar si es necesario
id_list = list(set(id_list))  # Eliminar duplicados
print(f"Se encontraron {len(id_list)} IDs únicos.")

# Lista para almacenar información de trabajos
job_list = []
fecha_actual = datetime.now().strftime("%Y-%m-%d")

# Obtener información de cada trabajo
for job_id in id_list:
    # URLs de la vacante
    job_url_api = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id}"
    job_url_decent = f"https://www.linkedin.com/jobs/view/{job_id}"  # URL limpia

    # Solicitar datos del trabajo
    job_response = requests.get(job_url_api)
    if job_response.status_code != 200:
        continue  # Saltar si hay error en la solicitud

    # Parsear datos del trabajo
    job_soup = BeautifulSoup(job_response.text, "html.parser")
    job_post = {
        "Estado": "Postulado",
        "Posición": None,
        "Fecha de Postulación": fecha_actual,
        "Plataforma": "LinkedIn",
        "Empresa": None,
        "Rubro": None,
        "Nombre del Reclutador": None,
        "Link Posición": job_url_decent,
        "Link Empresa": None,
        "Link Reclutador": None,
    }

    # Extraer detalles del trabajo
    try:
        job_post["Posición"] = job_soup.find("h2", {"class": "topcard__title"}).text.strip()
    except AttributeError:
        pass

    try:
        company_tag = job_soup.find("a", {"class": "topcard__org-name-link"})
        job_post["Empresa"] = company_tag.text.strip()
        job_post["Link Empresa"] = company_tag.get("href")
    except AttributeError:
        pass

    try:
        criterios = job_soup.find_all("span", {"class": "description__job-criteria-text"})
        if len(criterios) > 0:
            job_post["Rubro"] = criterios[3].text.strip()
    except AttributeError:
        pass

    try:
        recruiter_tag = job_soup.find("a", {"class": "base-card__full-link"})
        job_post["Nombre del Reclutador"] = recruiter_tag.text.strip()
        job_post["Link Reclutador"] = recruiter_tag.get("href")
    except AttributeError:
        pass

    # Agregar el trabajo a la lista
    job_list.append(job_post)

# Ordenar trabajos por fecha de publicación y limitar a 30
job_list = sorted(job_list, key=lambda x: x["Fecha de Postulación"], reverse=True)[:70]

# Guardar los resultados en un archivo Excel
jobs_df = pd.DataFrame(job_list)
jobs_df.to_excel("LinkedIn_Recent_Jobs_Organized.xlsx", index=False, engine="openpyxl")

print("Se han guardado los resultados en LinkedIn_Recent_Jobs_Organized.xlsx")
# Out:
# Se encontraron 73 IDs únicos.
# Se han guardado los resultados en LinkedIn_Recent_Jobs_Organized.xlsx

# %%
# Create a pandas DataFrame using the list of job dictionaries 'job_list'
jobs_df = pd.DataFrame(job_list)
jobs_df
# Out:
#        Estado                                Posición Fecha de Postulación  \
# 0   Postulado                   Business Data Analyst           2025-01-14
# 1   Postulado  Healthcare Data Analyst (SQL/ Tableau)           2025-01-14
# 2   Postulado                            Data Analyst           2025-01-14
# 3   Postulado                            Data Analyst           2025-01-14
# 4   Postulado                  Data Analyst, New Grad           2025-01-14
# 5   Postulado                   Business Data Analyst           2025-01-14
# 6   Postulado                            Data Analyst           2025-01-14
# 7   Postulado                 Healthcare Data Analyst           2025-01-14
# 8   Postulado                     Senior Data Analyst           2025-01-14
# 9   Postulado                            Data Analyst           2025-01-14
# 10  Postulado                            Data Analyst           2025-01-14
# 11  Postulado                            Data Analyst           2025-01-14
# 12  Postulado                            Data Analyst           2025-01-14
# 13  Postulado                   Business Data Analyst           2025-01-14
# 14  Postulado                            Data Analyst           2025-01-14
# 15  Postulado                            Data Analyst           2025-01-14
# 16  Postulado                            Data Analyst           2025-01-14
# 17  Postulado                            Data Analyst           2025-01-14
# 18  Postulado                            Data Analyst           2025-01-14
# 19  Postulado           Business Intelligence Analyst           2025-01-14
# 20  Postulado                            Data Analyst           2025-01-14
# 21  Postulado                            Data Analyst           2025-01-14
# 22  Postulado                            Data Analyst           2025-01-14
# 23  Postulado                            Data Analyst           2025-01-14
# 24  Postulado                     Senior Data Analyst           2025-01-14
# 25  Postulado                            Data Analyst           2025-01-14
# 26  Postulado                   Analyst, Data Science           2025-01-14
# 27  Postulado                            Data Analyst           2025-01-14
# 28  Postulado   Data Analyst with Power BI experience           2025-01-14
# 29  Postulado                            Data Analyst           2025-01-14
#
#    Plataforma                           Empresa  \
# 0    LinkedIn                    LeadStack Inc.
# 1    LinkedIn                           TECHEAD
# 2    LinkedIn     V-Soft Consulting Group, Inc.
# 3    LinkedIn                         PrudentRx
# 4    LinkedIn                            Stripe
# 5    LinkedIn                            Slalom
# 6    LinkedIn                            McAfee
# 7    LinkedIn                           Concert
# 8    LinkedIn                     Next Ventures
# 9    LinkedIn              Link Solutions, Inc.
# 10   LinkedIn                     Lumata Health
# 11   LinkedIn                    HCA Healthcare
# 12   LinkedIn                       Anthos|Home
# 13   LinkedIn                            Slalom
# 14   LinkedIn                   Walker & Dunlop
# 15   LinkedIn                          CapMetro
# 16   LinkedIn                  INSPYR Solutions
# 17   LinkedIn                    Compunnel Inc.
# 18   LinkedIn                         ThirdLove
# 19   LinkedIn     Refuel Operating Company, LLC
# 20   LinkedIn                           Harnham
# 21   LinkedIn                       HUGO by RGP
# 22   LinkedIn                            ECLARO
# 23   LinkedIn                               ZBD
# 24   LinkedIn                           Upstart
# 25   LinkedIn                           Siemens
# 26   LinkedIn              Toyota North America
# 27   LinkedIn  Pacific Gas and Electric Company
# 28   LinkedIn               Access Search, Inc.
# 29   LinkedIn           Pyramid Consulting, Inc
#
#                                                 Rubro  \
# 0   Transportation, Logistics, Supply Chain and St...
# 1                           Hospitals and Health Care
# 2                       IT Services and IT Consulting
# 3                                   Research Services
# 4   Software Development, Financial Services, and ...
# 5                    Business Consulting and Services
# 6                       Computer and Network Security
# 7                   Information Technology & Services
# 8                           Hospitals and Health Care
# 9                       IT Services and IT Consulting
# 10                      IT Services and IT Consulting
# 11                          Hospitals and Health Care
# 12                           Non-profit Organizations
# 13                   Business Consulting and Services
# 14                                 Financial Services
# 15                               Truck Transportation
# 16                      IT Services and IT Consulting
# 17                      IT Services and IT Consulting
# 18                         Retail Apparel and Fashion
# 19                                             Retail
# 20                                          Education
# 21  Agriculture, Construction, Mining Machinery Ma...
# 22                                          Utilities
# 23               Technology, Information and Internet
# 24                                 Financial Services
# 25                 Automation Machinery Manufacturing
# 26                        Motor Vehicle Manufacturing
# 27                                          Utilities
# 28    Wholesale Hardware, Plumbing, Heating Equipment
# 29                      IT Services and IT Consulting
#
#          Nombre del Reclutador                                  Link Posición  \
# 0                 Waseem Ahmad  https://www.linkedin.com/jobs/view/4119059667
# 1                         None  https://www.linkedin.com/jobs/view/4124762592
# 2             Kagitapu Alekhya  https://www.linkedin.com/jobs/view/4109686813
# 3                         None  https://www.linkedin.com/jobs/view/4111283336
# 4                         None  https://www.linkedin.com/jobs/view/4107169341
# 5                         None  https://www.linkedin.com/jobs/view/4103397998
# 6                         None  https://www.linkedin.com/jobs/view/4102473051
# 7                 Beau Bristow  https://www.linkedin.com/jobs/view/4114594063
# 8                Matthew Gomez  https://www.linkedin.com/jobs/view/4121823965
# 9                         None  https://www.linkedin.com/jobs/view/4115769502
# 10                        None  https://www.linkedin.com/jobs/view/4095622294
# 11               Angela Morris  https://www.linkedin.com/jobs/view/4117997760
# 12                        None  https://www.linkedin.com/jobs/view/4125461097
# 13                        None  https://www.linkedin.com/jobs/view/4103901346
# 14                        None  https://www.linkedin.com/jobs/view/4119482317
# 15                        None  https://www.linkedin.com/jobs/view/4095609362
# 16                        None  https://www.linkedin.com/jobs/view/4107122282
# 17               Priyesh Parab  https://www.linkedin.com/jobs/view/4121298979
# 18                        None  https://www.linkedin.com/jobs/view/4099359251
# 19  Karen Oldiges, PHR, SHRMCP  https://www.linkedin.com/jobs/view/4119841757
# 20                 Oisín Ennis  https://www.linkedin.com/jobs/view/4122383843
# 21                        None  https://www.linkedin.com/jobs/view/4102560295
# 22                        None  https://www.linkedin.com/jobs/view/4123350434
# 23                        None  https://www.linkedin.com/jobs/view/4121192850
# 24                        None  https://www.linkedin.com/jobs/view/4093403373
# 25                        None  https://www.linkedin.com/jobs/view/4119558846
# 26                        None  https://www.linkedin.com/jobs/view/4091689773
# 27                        None  https://www.linkedin.com/jobs/view/4119217467
# 28               Dane Robinson  https://www.linkedin.com/jobs/view/4118712599
# 29                        None  https://www.linkedin.com/jobs/view/4110244689
#
#                                          Link Empresa  \
# 0   https://www.linkedin.com/company/leadstack-inc...
# 1   https://www.linkedin.com/company/techead?trk=p...
# 2   https://www.linkedin.com/company/vsoftconsulti...
# 3   https://www.linkedin.com/company/prudentrx?trk...
# 4   https://www.linkedin.com/company/stripe?trk=pu...
# 5   https://www.linkedin.com/company/slalom-consul...
# 6   https://www.linkedin.com/company/mcafee?trk=pu...
# 7   https://www.linkedin.com/company/concert-genet...
# 8   https://uk.linkedin.com/company/next-ventures?...
# 9   https://www.linkedin.com/company/link-solution...
# 10  https://www.linkedin.com/company/lumatahealth?...
# 11  https://www.linkedin.com/company/hca?trk=publi...
# 12  https://www.linkedin.com/company/anthos-home?t...
# 13  https://www.linkedin.com/company/slalom-consul...
# 14  https://www.linkedin.com/company/walker-dunlop...
# 15  https://www.linkedin.com/company/capmetro?trk=...
# 16  https://www.linkedin.com/company/inspyrsolutio...
# 17  https://www.linkedin.com/company/compunnel-sof...
# 18  https://www.linkedin.com/company/thirdlove?trk...
# 19  https://www.linkedin.com/company/refuel-operat...
# 20  https://uk.linkedin.com/company/harnham?trk=pu...
# 21  https://www.linkedin.com/company/hugobyrgp?trk...
# 22  https://www.linkedin.com/company/eclaro?trk=pu...
# 23  https://www.linkedin.com/company/zebedeeio?trk...
# 24  https://www.linkedin.com/company/upstart-netwo...
# 25  https://de.linkedin.com/company/siemens?trk=pu...
# 26  https://www.linkedin.com/company/toyota-north-...
# 27  https://www.linkedin.com/company/pacificgasand...
# 28  https://www.linkedin.com/company/access-search...
# 29  https://www.linkedin.com/company/pyramid-consu...
#
#                                       Link Reclutador
# 0   https://www.linkedin.com/in/waseem-ahmad-20576...
# 1                                                None
# 2   https://www.linkedin.com/in/kagitapu-alekhya-1...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7             https://www.linkedin.com/in/beaubristow
# 8            https://www.linkedin.com/in/matt-a-gomez
# 9                                                None
# 10                                               None
# 11  https://www.linkedin.com/in/angela-morris-a6aa...
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17          https://www.linkedin.com/in/priyesh-parab
# 18                                               None
# 19               https://www.linkedin.com/in/koldiges
# 20  https://www.linkedin.com/in/ois%C3%ADn-ennis-0...
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28           https://www.linkedin.com/in/robinsondane
# 29                                               None
